# %% [markdown]
# # DATA FRAMES

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("../../data/bodyfat.txt", delimiter=" ", decimal=".", encoding="utf-8")

# %%
df
# Out:
#      Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 1     1.0708  12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 2     1.0853   6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 3     1.0414  25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 4     1.0751  10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 5     1.0340  28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
# ..       ...   ...  ...     ...     ...   ...    ...      ...    ...    ...
# 248   1.0736  11.0   70  134.25   67.00  34.9   89.2     83.6   88.8   49.6
# 249   1.0236  33.6   72  201.00   69.75  40.9  108.5    105.0  104.5   59.6
# 250   1.0328  29.3   72  186.75   66.00  38.9  111.1    111.5  101.7   60.3
# 251   1.0399  26.0   72  190.75   70.50  38.9  108.3    101.3   97.8   56.0
# 252   1.0271  31.9   74  207.50   70.00  40.8  112.4    108.5  107.1   59.3
#
#      Knee  Ankle  Biceps  Forearm  Wrist
# ...

# %%
df.groupby('Age').aggregate([min])
# Out:
#     Density   Fat  Weight Height  Neck  Chest Abdomen    Hip Thigh  Knee  \
#         min   min     min    min   min    min     min    min   min   min
# Age
# 22   1.0414   6.1  154.00  66.25  34.0   93.6    83.0   98.7  58.7  37.3
# 23   1.0708   9.4  154.25  67.75  35.5   92.1    77.1   93.9  56.1  36.1
# 24   1.0340  14.2  156.00  70.75  34.4   92.7    81.9   95.3  56.4  36.5
# 25   1.0322   4.1  143.75  69.75  35.2   92.3    76.5   92.1  51.9  35.7
# 26   1.0416   7.1  152.25  69.00  35.4   92.9    77.6   93.5  56.9  35.9
# 27   1.0510   3.7  133.25  64.75  34.1   88.5    72.8   88.5  50.1  34.5
# 28   1.0287  10.0  151.25  67.75  34.5   90.2    76.3   95.8  57.3  35.5
# 29   1.0790   5.7  160.25  69.00  36.7   93.5    83.5   98.7  58.5  35.3
# 30   1.0505  12.5  136.50  68.75  35.9   88.7    76.6   89.8  50.1  34.8
# 31   1.0468   9.4  140.25  67.50  33.9   86.0    76.4   91.5  52.5  35.3
# 32   1.0468  11.9  148.75  69.50  35.5   86.7    80.0   93.4  54.9  36.2
# ...

# %%
? pd.read_csv
