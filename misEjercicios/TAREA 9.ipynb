# %% [markdown]
# # TAREA 9

# %% [markdown]
# Carga el CSV de la carpeta de datos del tema llamado run.csv y responde a las siguientes preguntas.

# %%
import pandas as pd
import numpy as np

# %%
run = pd.read_csv("../data/run.csv")

# %%
df=run.copy()

# %%
df
# Out:
#     Unnamed: 0  pulso.antes  pulso.despues hace.deporte fuma genero  altura  \
# 0            1           48             54           no   si      H    68.0
# 1            2           54             56           no   si      H    69.0
# 2            3           54             50           no   no      H    69.0
# 3            4           58             70           si   no      H    72.0
# 4            5           58             58           no   no      H    66.0
# ..         ...          ...            ...          ...  ...    ...     ...
# 87          88           92             94           no   si      H    69.0
# 88          89           94             92           no   si      M    62.0
# 89          90           96            140           si   no      M    61.0
# 90          91           96            116           si   no      M    68.0
# 91          92          100            115           si   si      M    63.0
#
#     peso tipo.actividad
# 0    150           nula
# ...

# %%
run
# Out:
#     Unnamed: 0  pulso.antes  pulso.despues hace.deporte fuma genero  altura  \
# 0            1           48             54           no   si      H    68.0
# 1            2           54             56           no   si      H    69.0
# 2            3           54             50           no   no      H    69.0
# 3            4           58             70           si   no      H    72.0
# 4            5           58             58           no   no      H    66.0
# ..         ...          ...            ...          ...  ...    ...     ...
# 87          88           92             94           no   si      H    69.0
# 88          89           94             92           no   si      M    62.0
# 89          90           96            140           si   no      M    61.0
# 90          91           96            116           si   no      M    68.0
# 91          92          100            115           si   si      M    63.0
#
#     peso tipo.actividad
# 0    150           nula
# ...

# %%
run.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   X          92 non-null     int64
#  1   p.antes    92 non-null     int64
#  2   p.despues  92 non-null     int64
#  3   hace.dep   92 non-null     object
#  4   fuma       92 non-null     object
#  5   genero     92 non-null     object
#  6   altura     92 non-null     float64
#  7   peso       92 non-null     int64
#  8   tipo.act   92 non-null     object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 6.6+ KB

# %%
run.shape
# Out:
# (92, 9)

# %% [markdown]
# ### Preguntas de esta tarea

# %% [markdown]
# #### 1
# Indica cuantos estudiantes formaron parte del estudio de deporte

# %%
nAlum=run.shape[0]
print("%i estudiantes formaron parte del estudio." %nAlum)
# Out:
# 92 estudiantes formaron parte del estudio.

# %% [markdown]
# **¿Cómo se modifica el nombre de las columnas en python?**

# %% [markdown]
# con el parametro columns = [vector] dentro de la función df=pd.DataFrame()

# %%
run.columns=['X','p.antes','p.despues','hace.dep','fuma','genero','altura','peso','tipo.act']

# %%
run.index
# Out:
# RangeIndex(start=0, stop=92, step=1)

# %%
# ?np.shape

# %% [markdown]
# #### 2
# Indica cuantos individuos son hombres y cuantos son mujeres

# %%
gen=run.groupby('genero').count().X
print("%i individuos son mujer y %i son hombre."%(gen[1],gen[0]))
# Out:
# 35 individuos son mujer y 57 son hombre.

# %% [markdown]
# #### 3
# Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio y compara el valor de los que hacen ejercicio habitualmente y los que no. ¿Observas mucha diferencia?

# %%
run
# Out:
#      X  p.antes  p.despues hace.dep fuma genero  altura  peso  tipo.act
# 0    1       48         54       no   si      H    68.0   150      nula
# 1    2       54         56       no   si      H    69.0   145  moderada
# 2    3       54         50       no   no      H    69.0   160  moderada
# 3    4       58         70       si   no      H    72.0   145  moderada
# 4    5       58         58       no   no      H    66.0   135   intensa
# ..  ..      ...        ...      ...  ...    ...     ...   ...       ...
# 87  88       92         94       no   si      H    69.0   150  moderada
# 88  89       94         92       no   si      M    62.0   131  moderada
# 89  90       96        140       si   no      M    61.0   140  moderada
# 90  91       96        116       si   no      M    68.0   116  moderada
# 91  92      100        115       si   si      M    63.0   121  moderada
#
# [92 rows x 9 columns]

# %%
run = df

# %%
run.columns=['X','p.antes','p.despues','hace.dep','fuma','genero','altura','peso','tipo.act']

# %%
def var_pulso(x):    
    x['var_p']=(x['p.despues']-x['p.antes'])/x['p.antes']
    return x
#var_pulso(run) #agrega una nueva variable al Data Frame
#run.groupby('hace.dep').mean()
run.groupby('hace.dep').agg([np.mean,var_pulso]) # error
# run.groupby('hace.dep').apply(var_pulso) # no lo agrupa!!
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'p.despues'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     259             try:
# ...

# %%
run.groupby('hace.dep').mean()
# Out:
#                   X    p.antes  p.despues     altura        peso     var_p
# hace.dep
# no        47.017544  72.421053  72.315789  68.065789  141.122807  0.002095
# si        45.657143  73.600000  92.514286  69.778571  151.714286  0.262154

# %%
mp=100*run.groupby('hace.dep').mean()['var_p']
print(mp)
vpf=mp[1]-mp[0]
# Out:
# hace.dep
# no     0.209479
# si    26.215407
# Name: var_p, dtype: float64

# %%
print ("La variación media del pulso de los que %s hacen deporte es: %.3f %s" 
       %(mp.index[1],mp[1],'%'))
print ("La variación media del pulso de los que %s hacen deporte es: %.3f %s" 
       %(mp.index[0],mp[0], '%'))
print ("Hay una diferencia de un %.3f %s" %(vpf,'%'))
# Out:
# La variación media del pulso de los que si hacen deporte es: 26.215 %
# La variación media del pulso de los que no hacen deporte es: 0.209 %
# Hay una diferencia de un 26.006 %

# %% [markdown]
# #### 4
# Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio  para los estudiantes que hacen ejercicio habitualmente y compara el valor de los hombres con el de las mujeres. ¿Observas mucha diferencia?

# %%
run
# Out:
#      X  p.antes  p.despues hace.dep fuma genero  altura  peso  tipo.act  \
# 0    1       48         54       no   si      H    68.0   150      nula
# 1    2       54         56       no   si      H    69.0   145  moderada
# 2    3       54         50       no   no      H    69.0   160  moderada
# 3    4       58         70       si   no      H    72.0   145  moderada
# 4    5       58         58       no   no      H    66.0   135   intensa
# ..  ..      ...        ...      ...  ...    ...     ...   ...       ...
# 87  88       92         94       no   si      H    69.0   150  moderada
# 88  89       94         92       no   si      M    62.0   131  moderada
# 89  90       96        140       si   no      M    61.0   140  moderada
# 90  91       96        116       si   no      M    68.0   116  moderada
# 91  92      100        115       si   si      M    63.0   121  moderada
#
#        var_p
# 0   0.125000
# 1   0.037037
# 2  -0.074074
# 3   0.206897
# 4   0.000000
# ..       ...
# ...

# %%
# def filtro_dep(x):
#    return x['hace.dep']=='si'

# %%
# run.groupby('genero').filter(filtro_dep)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-235-4a845b254e26> in <module>
# ----> 1 run.groupby('genero').filter(filtro_dep)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in filter(self, func, dropna, *args, **kwargs)
#    1630             else:
#    1631                 # non scalars aren't allowed
# -> 1632                 raise TypeError(
#    1633                     f"filter function returned a {type(res).__name__}, "
#    1634                     "but expected a scalar bool"
#
# TypeError: filter function returned a Series, but expected a scalar bool

# %%
# filtro_dep(run)
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 87    False
# 88    False
# 89     True
# 90     True
# 91     True
# Name: hace.dep, Length: 92, dtype: bool

# %%
run[run['hace.dep']=='si']
# Out:
#      X  p.antes  p.despues hace.dep fuma genero  altura  peso  tipo.act  \
# 3    4       58         70       si   no      H   72.00   145  moderada
# 6    7       60         76       si   no      H   71.00   170   intensa
# 11  12       62         76       si   si      H   73.50   160   intensa
# 12  13       62         75       si   no      H   72.00   195  moderada
# 13  14       62         58       si   no      H   72.00   175   intensa
# 14  15       62        100       si   no      M   66.00   120  moderada
# 15  16       62         98       si   si      M   62.75   112  moderada
# 20  21       64         88       si   no      H   66.00   140  moderada
# 21  22       64         80       si   no      H   69.00   155  moderada
# 24  25       66         78       si   si      H   73.00   190     suave
# 25  26       66         82       si   si      H   69.00   175  moderada
# 26  27       66        102       si   no      H   70.00   130  moderada
# ...

# %%
varp_hm_dep=100*run[run['hace.dep']=='si'].groupby('genero').mean()['var_p']
print(varp_hm_dep)
varp_hm=varp_hm_dep[1]-varp_hm_dep[0]
# Out:
# genero
# H    19.176886
# M    41.572181
# Name: var_p, dtype: float64

# %%
print ("La variación media del pulso de las %s que hacen deporte es: %.3f %s" 
       %(varp_hm_dep.index[1],varp_hm_dep[1],'%'))
print ("La variación media del pulso de los %s que hacen deporte es: %.3f %s" 
       %(varp_hm_dep.index[0],varp_hm_dep[0], '%'))
print ("Hay una diferencia de un %.3f %s" %(varp_hm,'%'))
# Out:
# La variación media del pulso de las M que hacen deporte es: 41.572 %
# La variación media del pulso de los H que hacen deporte es: 19.177 %
# Hay una diferencia de un 22.395 %

# %% [markdown]
# #### 5
# Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio para los estudiantes que no hacen ejercicio habitualmente y compara el valor de los fumadores con los no fumadores. ¿Observas mucha diferencia?

# %%
run
# Out:
#      X  p.antes  p.despues hace.dep fuma genero  altura  peso  tipo.act  \
# 0    1       48         54       no   si      H    68.0   150      nula
# 1    2       54         56       no   si      H    69.0   145  moderada
# 2    3       54         50       no   no      H    69.0   160  moderada
# 3    4       58         70       si   no      H    72.0   145  moderada
# 4    5       58         58       no   no      H    66.0   135   intensa
# ..  ..      ...        ...      ...  ...    ...     ...   ...       ...
# 87  88       92         94       no   si      H    69.0   150  moderada
# 88  89       94         92       no   si      M    62.0   131  moderada
# 89  90       96        140       si   no      M    61.0   140  moderada
# 90  91       96        116       si   no      M    68.0   116  moderada
# 91  92      100        115       si   si      M    63.0   121  moderada
#
#        var_p
# 0   0.125000
# 1   0.037037
# 2  -0.074074
# 3   0.206897
# 4   0.000000
# ..       ...
# ...

# %%
run[run['hace.dep']=='no']
# Out:
#      X  p.antes  p.despues hace.dep fuma genero  altura  peso  tipo.act  \
# 0    1       48         54       no   si      H   68.00   150      nula
# 1    2       54         56       no   si      H   69.00   145  moderada
# 2    3       54         50       no   no      H   69.00   160  moderada
# 4    5       58         58       no   no      H   66.00   135   intensa
# 5    6       58         56       no   no      M   67.00   125  moderada
# 7    8       60         62       no   no      H   71.00   155  moderada
# 8    9       60         70       no   si      H   71.50   164  moderada
# 9   10       60         66       no   no      M   62.00   120  moderada
# 10  11       61         70       no   no      M   65.50   120  moderada
# 16  17       62         62       no   no      H   74.00   190     suave
# 17  18       62         66       no   no      H   70.00   155  moderada
# 18  19       62         68       no   si      H   73.00   155  moderada
# ...

# %%
run[run['hace.dep']=='no'].groupby('fuma').mean()
# Out:
#               X    p.antes  p.despues     altura        peso     var_p
# fuma
# no    45.512195  71.707317  71.512195  68.079268  138.195122 -0.000648
# si    50.875000  74.250000  74.375000  68.031250  148.625000  0.009122

# %%
varp_fum_ndep=100*run[run['hace.dep']=='no'].groupby('fuma').mean()['var_p']
print(varp_fum_ndep)
varp_fum=abs(varp_fum_ndep[0]-varp_fum_ndep[1])
# Out:
# fuma
# no   -0.064761
# si    0.912219
# Name: var_p, dtype: float64

# %%
print ("La variación media para los estudiantes que no hacen deporte y que %s fuman, es: %.3f %s" 
       %(varp_fum_ndep.index[1],varp_fum_ndep[1],'%'))
print ("La variación media para los estudiantes que no hacen deporte y que %s fuman, es: %.3f %s" 
       %(varp_fum_ndep.index[0],varp_fum_ndep[0], '%'))
print ("Hay una diferencia de un %.3f %s" %(varp_fum,'%'))
# Out:
# La variación media para los estudiantes que no hacen deporte y que si fuman, es: 0.912 %
# La variación media para los estudiantes que no hacen deporte y que no fuman, es: -0.065 %
# Hay una diferencia de un 0.977 %

# %% [markdown]
# #### 6
# Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio de todos los estudiantes según el tipo de actividad física que realizan. ¿Observas alguna diferencia?

# %%
run
# Out:
#      X  p.antes  p.despues hace.dep fuma genero  altura  peso  tipo.act  \
# 0    1       48         54       no   si      H    68.0   150      nula
# 1    2       54         56       no   si      H    69.0   145  moderada
# 2    3       54         50       no   no      H    69.0   160  moderada
# 3    4       58         70       si   no      H    72.0   145  moderada
# 4    5       58         58       no   no      H    66.0   135   intensa
# ..  ..      ...        ...      ...  ...    ...     ...   ...       ...
# 87  88       92         94       no   si      H    69.0   150  moderada
# 88  89       94         92       no   si      M    62.0   131  moderada
# 89  90       96        140       si   no      M    61.0   140  moderada
# 90  91       96        116       si   no      M    68.0   116  moderada
# 91  92      100        115       si   si      M    63.0   121  moderada
#
#        var_p
# 0   0.125000
# 1   0.037037
# 2  -0.074074
# 3   0.206897
# 4   0.000000
# ..       ...
# ...

# %%
100*run.groupby('tipo.act').mean()['var_p']
# Out:
# tipo.act
# intensa      1.347475
# moderada    14.015695
# nula        12.500000
# suave        3.747241
# Name: var_p, dtype: float64

# %%
100*run.groupby('tipo.act').mean()['var_p'].sort_values()
# Out:
# tipo.act
# intensa      1.347475
# suave        3.747241
# nula        12.500000
# moderada    14.015695
# Name: var_p, dtype: float64

# %%
help(pd.rank)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-246-0231b53c021d> in <module>
# ----> 1 help(pd.rank)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'rank'

# %% [markdown]
# ## RESPUESTAS DEL PROFESOR - EN R?

# %% [markdown]
# #### 1

# %%
nrow(df)

# %% [markdown]
# #### 2

# %%
table(df$genero)

# %% [markdown]
# #### 3

# %%
df$var = df$pulso.despues-df$pulso.antes
aggregate(df$var~ df$hace.deporte, FUN = mean)

# %% [markdown]
# #### 4

# %%
df$var = df$pulso.despues-df$pulso.antes
data = df[, df$hace.deporte == TRUE]
aggregate(data$var ~ data$genero, FUN = mean)
# Out:
#   File "<ipython-input-249-212186d718d6>", line 1
#     df$var = df$pulso.despues-df$pulso.antes
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 5

# %%
df$var = df$pulso.despues-df$pulso.antes
data = df[, df$hace.deporte == FALSE]
aggregate(data$var ~ data$fuma, FUN = mean)

# %% [markdown]
# #### 6

# %%
df$var = df$pulso.despues-df$pulso.antes
aggregate(df$var ~ df$tipo.actividad, FUN = mean)

# %% [markdown]
# ### RESPUESTAS COMPAÑEROS

# %% [markdown]
# #### 3

# %%
def var(df):
  return ((df['pulso.despues']-df['pulso.antes'])/df['pulso.antes'])*100

table = run.groupby('hace.deporte').aggregate({'pulso.antes' : np.mean, 'pulso.despues': np.mean })
var(table)
# Out:
# hace.deporte
# no    -0.145349
# si    25.698758
# dtype: float64

# %%
table_2 = run[run['hace.deporte'] == 'si'].groupby(
    'genero').aggregate({'pulso.antes' : np.mean, 'pulso.despues' : np.mean})
var(table_2)
# Out:
# genero
# H    18.446026
# M    39.438202
# dtype: float64

# %% [markdown]
# #### 4

# %%
df=run

# %%
# Se crea la variable booleana que evalúa los registros que cumplen o no la condición hacer deporte
hacen_deporte = df['hace.deporte'] == 'si'
print(hacen_deporte)
# Se filtra el data frame selecciona los estudiantes que hacen ejercicio habitualmente
df_filt = df[hacen_deporte] # Muestra los registros del data frame tales que hacen_deporte == TRUE
df_filt
df_filt.groupby('genero').mean()
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 87    False
# 88    False
# 89     True
# 90     True
# 91     True
# Name: hace.deporte, Length: 92, dtype: bool
#         Unnamed: 0  pulso.antes  pulso.despues     altura        peso
# genero
# H        38.083333    70.250000      83.208333  71.229167  162.000000
# M        62.181818    80.909091     112.818182  66.613636  129.272727

# %%
help(pd.get_group)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-c83261a70ae4> in <module>
# ----> 1 help(pd.get_group)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'get_group'
